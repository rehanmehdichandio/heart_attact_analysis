# %% [markdown]
# <a href="https://colab.research.google.com/github/rehanmehdichandio/heart_attact_analysis/blob/main/heart_atttack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/heart_attack_dataset.csv')

# %%
print('Dataset Information')
df.info()
# Out:
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 1000 non-null   object
#  1   Age                    1000 non-null   int64
#  2   Blood Pressure (mmHg)  1000 non-null   int64
#  3   Cholesterol (mg/dL)    1000 non-null   int64
#  4   Has Diabetes           1000 non-null   object
#  5   Smoking Status         1000 non-null   object
#  6   Chest Pain Type        1000 non-null   object
#  7   Treatment              1000 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#    Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0    Male   70                    181                  262           No
# 1  Female   55                    103                  253          Yes
# 2    Male   42                     95                  295          Yes
# 3    Male   84                    106                  270           No
# 4    Male   86                    187                  296          Yes
#
#   Smoking Status   Chest Pain Type                            Treatment
# 0          Never    Typical Angina                    Lifestyle Changes
# 1          Never   Atypical Angina                          Angioplasty
# 2        Current    Typical Angina                          Angioplasty
# 3          Never   Atypical Angina  Coronary Artery Bypass Graft (CABG)
# 4        Current  Non-anginal Pain                           Medication

# %%
df.describe(include='all')
# Out:
#         Gender          Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  \
# count     1000  1000.000000            1000.000000          1000.000000
# unique       2          NaN                    NaN                  NaN
# top     Female          NaN                    NaN                  NaN
# freq       510          NaN                    NaN                  NaN
# mean       NaN    60.338000             145.440000           223.789000
# std        NaN    17.317496              31.756525            42.787817
# min        NaN    30.000000              90.000000           150.000000
# 25%        NaN    45.000000             118.000000           185.000000
# 50%        NaN    60.500000             146.000000           225.500000
# 75%        NaN    76.000000             173.000000           259.000000
# max        NaN    89.000000             199.000000           299.000000
#
#        Has Diabetes Smoking Status   Chest Pain Type          Treatment
# ...

# %%
print('\n Print Missing values')
df.isnull().sum()
# Out:
#  Print Missing values
# Gender                   0
# Age                      0
# Blood Pressure (mmHg)    0
# Cholesterol (mg/dL)      0
# Has Diabetes             0
# Smoking Status           0
# Chest Pain Type          0
# Treatment                0
# dtype: int64

# %%
df.dtypes
# Out:
# Gender                   object
# Age                       int64
# Blood Pressure (mmHg)     int64
# Cholesterol (mg/dL)       int64
# Has Diabetes             object
# Smoking Status           object
# Chest Pain Type          object
# Treatment                object
# dtype: object

# %%
df['Gender'] = df['Gender'].astype('category')
df['Has Diabetes'] = df['Has Diabetes'].astype('category')
df['Smoking Status'] = df['Smoking Status'].astype('category')
df['Chest Pain Type'] = df['Chest Pain Type'].astype('category')
df['Treatment'] = df['Treatment'].astype('category')

# %%
df.dtypes
# Out:
# Gender                   category
# Age                         int64
# Blood Pressure (mmHg)       int64
# Cholesterol (mg/dL)         int64
# Has Diabetes             category
# Smoking Status           category
# Chest Pain Type          category
# Treatment                category
# dtype: object

# %%
print('\n Value Counts for Categorical Columns: ')
print(df['Gender'].value_counts())
print(df['Has Diabetes'].value_counts())
print(df['Smoking Status'].value_counts())
print(df['Chest Pain Type'].value_counts())
print(df['Treatment'].value_counts())
# Out:
#  Value Counts for Categorical Columns:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64
# Has Diabetes
# Yes    517
# No     483
# Name: count, dtype: int64
# Smoking Status
# Never      352
# Current    325
# Former     323
# Name: count, dtype: int64
# Chest Pain Type
# Non-anginal Pain    261
# Asymptomatic        255
# Typical Angina      243
# Atypical Angina     241
# Name: count, dtype: int64
# Treatment
# Lifestyle Changes                      269
# Coronary Artery Bypass Graft (CABG)    252
# Angioplasty                            247
# Medication                             232
# Name: count, dtype: int64

# %%
#Gender Distribution
# plt.figure(figsize=(8,6))
# # sns.countplot(x='Gender', data=df)
# # plt.xlabel('Gender')
# # plt.ylabel('Count')
# # plt.show()


fig, ax =plt.subplots()
sns.countplot(x='Gender', data=df)
ax.set_xlabel("Gender")
ax.set_ylabel('Count')
ax.set_title('Gender Count')
plt.show()

# %%
#Age Distribution
plt.figure(figsize=(8,6))
sns.histplot(df['Age'], kde = True, bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Blood Pressure Distribution
plt.figure(figsize =(8, 6))
sns.histplot(df['Blood Pressure (mmHg)'], kde =True, bins = 30 )
plt.title('Blood Pressure (mmHg) Distribution')
plt.xlabel('Blood Pressure (mmHg)')
plt.ylabel('Count')
plt.show()

# %%
#Cholesterol Dsitribution
plt.figure(figsize = (8,6))
sns.histplot(df['Cholesterol (mg/dL)'], kde=True, bins =30)
plt.title('Cholesterol Distribution')
plt.xlabel('Cholesterol')
plt.ylabel('Counts')
plt.show()

# %%
#Age vs Treatment
plt.figure(figsize = (8,6))
sns.boxplot(x='Treatment', y='Age', data=df)
plt.title('Age vs Treatment')
plt.xlabel('Treatment')
plt.xticks(rotation=90)
plt.ylabel('Age')
plt.show()

# %%
#Blood Pressure vs Treatment
plt.figure(figsize = (8,6))
sns.boxplot(x='Treatment', y='Blood Pressure (mmHg)', data=df)
plt.title('Blood Pressure vs Treatment')
plt.xlabel('Treatment')
plt.xticks(rotation= 90)
plt.ylabel('Blood Pressure (mmHg)')
plt.show()

# %%
#Blood Pressure Vs Treatment

plt.figure(figsize=(8,10))
sns.boxplot(x='Treatment', y='Blood Pressure (mmHg)', data=df)
plt.title('Blood Pressure Vs Treatment')
plt.xlabel("Treatment")
plt.xticks(rotation = 90)
plt.ylabel('Blood Presure (mmHg)')
plt.show()
